# %% [markdown]
# <a href="https://colab.research.google.com/github/gondore/nsdc-crafter/blob/main/DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gymnasium crafter stable_baselines3 shimmy[gym-v26]

# %% [markdown]
# # **Quick Start**
# Replace '/content/sample_data/new_mount_2' with a new empty folder path in google colab. Replace other file paths with the same path you used appropriately.
#
# - After training, you will get a collection of short videos inside the file path – these are videos of each episode.
# - We can use the dedicated video concatenation function to combine all the videos together as final_training_video.mp4.
# - data can be found through the stats.jsonl file generated in the file path after training

# %%
import gymnasium as gym
import crafter


env = crafter.Env()
env = crafter.Recorder(
  env, '/content/sample_data/NSDC_official_training',
  save_stats=True,
  save_video=True,
  save_episode=False,
)
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
from skimage.color import rgb2gray
from skimage import transform
import matplotlib.pyplot as plt
from collections import deque
import random

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Preprocessing observation space**
#
# We could experiment with performance by playing with:
#
# - grayscale frames
# - normalizing pixel values
# - resize preprocessed frame/ cut off the health bar and inventory maybe?

# %%
def preprocess_frame(frame):
    # Greyscale frame
    gray = rgb2gray(frame)

    # Normalize Pixel Values
    normalized_frame = frame/255.0

    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [110,84])

    return preprocessed_frame # 110x84x1 frame

# %%
# try out using tensorboard maybe?
#writer = tf.summary.FileWriter("/tensorboard/dqn/1")

## Losses
#tf.summary.scalar("Loss", DQNetwork.loss)

#write_op = tf.summary.merge_all()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import gymnasium as gym
import matplotlib.pyplot as plt



class ConvDQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(ConvDQN, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=8, stride=4),  # input channels = 3 for RGB images
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        self.fc_layers = nn.Sequential(
            nn.Linear(64 * 4 * 4, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)  # Change image format from HWC to CHW expected by PyTorch
        conv_out = self.conv_layers(x).reshape(x.size(0), -1)  # Flatten the output for the FC layers
        return self.fc_layers(conv_out)

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        return np.array(state), action, reward, np.array(next_state), done

    def __len__(self):
        return len(self.buffer)

# %%
class DQNAgent:
    def __init__(self, state_dim, action_dim, replay_buffer):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.replay_buffer = replay_buffer
        self.model = ConvDQN(state_dim, action_dim)
        self.optimizer = optim.Adam(self.model.parameters())
        self.criterion = nn.MSELoss()
        self.epsilon = 0.99
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.gamma = 0.99

      # Initialize target model and set weights equal to the model weights
        self.target_model = ConvDQN(state_dim, action_dim)
        self.update_target()

    def update_target(self):
        self.target_model.load_state_dict(self.model.state_dict())


    def act(self, state):
        if random.random() > self.epsilon:
            state = torch.FloatTensor(state).unsqueeze(0)
            q_values = self.model(state)
            action = q_values.max(1)[1].item()
        else:
            action = random.randrange(self.action_dim)
        return action

    def train(self, batch_size):
        if len(self.replay_buffer) < batch_size:
            return
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(batch_size)
        states = torch.FloatTensor(states)
        next_states = torch.FloatTensor(next_states)
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        dones = torch.FloatTensor(dones)

        q_values = self.model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.target_model(next_states).max(1)[0]
        expected_q_values = rewards + self.gamma * next_q_values * (1 - dones)

        loss = self.criterion(q_values, expected_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
state_dim = np.prod(env.observation_space.shape)  # This ensures a flat vector input size is correctly identified
action_dim = env.action_space.n

action_dim = env.action_space.n
replay_buffer = ReplayBuffer(10000)
agent = DQNAgent(state_dim, action_dim, replay_buffer)

def train_dqn(episodes, target_update=10):
    rewards = []
    for episode in range(episodes):
        if episode % target_update == 0:
          agent.update_target()
        state = env.reset()
        episode_reward = 0
        while True:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            replay_buffer.push(state, action, reward, next_state, done)
            state = next_state
            episode_reward += reward
            agent.train(32)
            if done:
                break
        rewards.append(episode_reward)
        print(f'Episode: {episode}, Reward: {episode_reward}')
        agent.epsilon = max(agent.epsilon_min, agent.epsilon_decay * agent.epsilon)  # Decay epsilon
    return rewards

episodes = 1000
rewards = train_dqn(episodes)
# Out:
# Episode: 0, Reward: 2.099999999999999
# Episode: 1, Reward: 2.099999999999999
# Episode: 2, Reward: 2.0999999999999996
# Episode: 3, Reward: 2.099999999999999
# Episode: 4, Reward: 2.0999999999999996
# Episode: 5, Reward: 1.0999999999999992
# Episode: 6, Reward: 2.099999999999999
# Episode: 7, Reward: 0.10000000000000009
# Episode: 8, Reward: 0.10000000000000006
# Episode: 9, Reward: 0.10000000000000014
# Episode: 10, Reward: -0.9
# Episode: 11, Reward: 2.099999999999999
# Episode: 12, Reward: 1.1000000000000003
# Episode: 13, Reward: -0.9000000000000001
# Episode: 14, Reward: 0.09999999999999992
# Episode: 15, Reward: 3.0999999999999996
# Episode: 16, Reward: -0.9
# Episode: 17, Reward: 2.099999999999999
# Episode: 18, Reward: 2.0999999999999996
# Episode: 19, Reward: 1.1000000000000003
# Episode: 20, Reward: 0.1
# Episode: 21, Reward: 0.09999999999999998
# Episode: 22, Reward: 2.1
# Episode: 23, Reward: 0.09999999999999998
# Episode: 24, Reward: 1.1000000000000003
# Episode: 25, Reward: -0.9000000000000001
# Episode: 26, Reward: -0.9000000000000001
# Episode: 27, Reward: 2.099999999999999
# Episode: 28, Reward: 0.10000000000000009
# Episode: 29, Reward: -0.8999999999999999
# Episode: 30, Reward: 2.0999999999999996
# Episode: 31, Reward: 2.0999999999999996
# Episode: 32, Reward: 1.1
# Episode: 33, Reward: 0.09999999999999998
# Episode: 34, Reward: 2.099999999999999
# Episode: 35, Reward: 2.099999999999999
# Episode: 36, Reward: 1.1000000000000003
# Episode: 37, Reward: 2.0999999999999996
# Episode: 38, Reward: 0.09999999999999987
# Episode: 39, Reward: 3.0999999999999996
# Episode: 40, Reward: 0.09999999999999992
# Episode: 41, Reward: 0.09999999999999992
# Episode: 42, Reward: 0.10000000000000006
# Episode: 43, Reward: 1.1
# Episode: 44, Reward: 0.10000000000000009
# Episode: 45, Reward: 0.09999999999999995
# Episode: 46, Reward: 0.10000000000000006
# Episode: 47, Reward: 3.099999999999999
# Episode: 48, Reward: 2.0999999999999996
# Episode: 49, Reward: 2.1
# Episode: 50, Reward: 0.10000000000000006
# Episode: 51, Reward: 3.099999999999999
# Episode: 52, Reward: 2.099999999999999
# Episode: 53, Reward: 0.0999999999999997
# Episode: 54, Reward: 2.099999999999999
# Episode: 55, Reward: 0.09999999999999998
# Episode: 56, Reward: 2.099999999999999
# Episode: 57, Reward: 3.0999999999999996
# Episode: 58, Reward: 0.09999999999999992
# Episode: 59, Reward: 1.1
# Episode: 60, Reward: -0.9000000000000001
# Episode: 61, Reward: 3.099999999999999
# Episode: 62, Reward: 3.0999999999999996
# Episode: 63, Reward: 2.1000000000000005
# Episode: 64, Reward: -0.9000000000000001
# Episode: 65, Reward: -0.9000000000000001
# Episode: 66, Reward: 2.099999999999999
# Episode: 67, Reward: 2.099999999999999
# Episode: 68, Reward: 2.1000000000000005
# Episode: 69, Reward: 3.099999999999999
# Episode: 70, Reward: 2.0999999999999996
# Episode: 71, Reward: 0.10000000000000003
# Episode: 72, Reward: 0.10000000000000003
# Episode: 73, Reward: 1.1000000000000003
# Episode: 74, Reward: 2.0999999999999996
# Episode: 75, Reward: 2.0999999999999996
# Episode: 76, Reward: 2.099999999999999
# Episode: 77, Reward: 0.09999999999999998
# Episode: 78, Reward: 1.1
# Episode: 79, Reward: 3.0999999999999996
# Episode: 80, Reward: 2.099999999999999
# Episode: 81, Reward: 2.099999999999999
# Episode: 82, Reward: 2.099999999999999
# Episode: 83, Reward: 2.1
# Episode: 84, Reward: 1.0999999999999992
# Episode: 85, Reward: 2.099999999999999
# Episode: 86, Reward: 0.09999999999999981
# Episode: 87, Reward: 2.0999999999999996
# Episode: 88, Reward: 3.099999999999999
# Episode: 89, Reward: 4.1
# Episode: 90, Reward: 2.1
# Episode: 91, Reward: 2.0999999999999996
# Episode: 92, Reward: 3.099999999999999
# Episode: 93, Reward: 3.099999999999999
# Episode: 94, Reward: 2.099999999999999
# Episode: 95, Reward: 2.0999999999999996
# Episode: 96, Reward: 0.09999999999999998
# Episode: 97, Reward: 3.099999999999999
# Episode: 98, Reward: 2.0999999999999996
# Episode: 99, Reward: 5.1
# Episode: 100, Reward: 4.1
# Episode: 101, Reward: 1.1
# Episode: 102, Reward: 2.099999999999999
# Episode: 103, Reward: -0.9000000000000001
# Episode: 104, Reward: 0.10000000000000009
# Episode: 105, Reward: 2.099999999999999
# Episode: 106, Reward: 2.1
# Episode: 107, Reward: 2.099999999999999
# Episode: 108, Reward: 2.099999999999999
# Episode: 109, Reward: 1.1
# Episode: 110, Reward: 3.099999999999999
# Episode: 111, Reward: 2.099999999999999
# Episode: 112, Reward: 2.099999999999999
# Episode: 113, Reward: 3.099999999999999
# Episode: 114, Reward: 1.1000000000000003
# Episode: 115, Reward: -0.9000000000000001
# Episode: 116, Reward: 3.099999999999999
# Episode: 117, Reward: 2.099999999999999
# Episode: 118, Reward: 2.0999999999999996
# Episode: 119, Reward: 2.1
# Episode: 120, Reward: -0.8999999999999999
# Episode: 121, Reward: 2.1
# Episode: 122, Reward: 1.1
# Episode: 123, Reward: 2.099999999999999
# Episode: 124, Reward: 0.10000000000000006
# Episode: 125, Reward: 1.1000000000000003
# Episode: 126, Reward: 3.099999999999999
# Episode: 127, Reward: 1.1000000000000003
# Episode: 128, Reward: 3.099999999999999
# Episode: 129, Reward: 0.10000000000000006
# Episode: 130, Reward: 1.1
# Episode: 131, Reward: 2.0999999999999996
# Episode: 132, Reward: 3.099999999999999
# Episode: 133, Reward: 2.0999999999999996
# Episode: 134, Reward: 1.1000000000000003
# Episode: 135, Reward: 3.099999999999999
# Episode: 136, Reward: 1.1000000000000003
# Episode: 137, Reward: 1.1
# Episode: 138, Reward: 2.099999999999999
# Episode: 139, Reward: 2.0999999999999996
# Episode: 140, Reward: 4.1
# Episode: 141, Reward: 0.09999999999999998
# Episode: 142, Reward: 2.099999999999999
# Episode: 143, Reward: 0.09999999999999987
# Episode: 144, Reward: -0.8999999999999999
# Episode: 145, Reward: 1.1000000000000003
# Episode: 146, Reward: 1.1000000000000003
# Episode: 147, Reward: 3.099999999999999
# Episode: 148, Reward: 1.1
# Episode: 149, Reward: 3.099999999999999
# Episode: 150, Reward: 2.099999999999999
# Episode: 151, Reward: 0.10000000000000009
# Episode: 152, Reward: 2.099999999999999
# Episode: 153, Reward: 1.1000000000000005
# Episode: 154, Reward: -0.9
# Episode: 155, Reward: 0.10000000000000009
# Episode: 156, Reward: -0.9
# Episode: 157, Reward: 2.099999999999999
# Episode: 158, Reward: -0.9000000000000001
# Episode: 159, Reward: 2.099999999999999
# Episode: 160, Reward: 2.099999999999999
# Episode: 161, Reward: 1.1000000000000003
# Episode: 162, Reward: 3.099999999999999
# Episode: 163, Reward: 3.099999999999999
# Episode: 164, Reward: 0.10000000000000006
# Episode: 165, Reward: 2.099999999999999
# Episode: 166, Reward: 4.1
# Episode: 167, Reward: 3.099999999999999
# Episode: 168, Reward: 1.1000000000000005
# Episode: 169, Reward: 2.1
# Episode: 170, Reward: 2.099999999999999
# Episode: 171, Reward: 2.1
# Episode: 172, Reward: 3.099999999999999
# Episode: 173, Reward: 2.099999999999999
# Episode: 174, Reward: 2.0999999999999996
# Episode: 175, Reward: 1.1000000000000003
# Episode: 176, Reward: 4.099999999999999
# Episode: 177, Reward: 3.1
# Episode: 178, Reward: 2.099999999999999
# Episode: 179, Reward: 1.1000000000000003
# Episode: 180, Reward: 1.1000000000000003
# Episode: 181, Reward: 3.0999999999999996
# Episode: 182, Reward: 0.10000000000000003
# Episode: 183, Reward: -0.8999999999999999
# Episode: 184, Reward: 3.099999999999999
# Episode: 185, Reward: 1.1000000000000003
# Episode: 186, Reward: 4.1
# Episode: 187, Reward: 0.09999999999999998
# Episode: 188, Reward: -0.9
# Episode: 189, Reward: 2.099999999999999
# Episode: 190, Reward: 1.1
# Episode: 191, Reward: 3.099999999999999
# Episode: 192, Reward: 0.09999999999999998
# Episode: 193, Reward: 1.1000000000000003
# Episode: 194, Reward: 2.099999999999999
# Episode: 195, Reward: 2.099999999999999
# Episode: 196, Reward: 1.0999999999999999
# Episode: 197, Reward: 2.099999999999999
# Episode: 198, Reward: 1.1
# Episode: 199, Reward: 1.1000000000000003
# Episode: 200, Reward: 4.1000000000000005
# Episode: 201, Reward: 3.099999999999999
# Episode: 202, Reward: 3.099999999999999
# Episode: 203, Reward: 3.0999999999999996
# Episode: 204, Reward: 2.099999999999999
# Episode: 205, Reward: 1.1000000000000003
# Episode: 206, Reward: -0.8999999999999999
# Episode: 207, Reward: 0.10000000000000009
# Episode: 208, Reward: 4.099999999999999
# Episode: 209, Reward: 1.1
# Episode: 210, Reward: 3.099999999999999
# Episode: 211, Reward: 1.1000000000000003
# Episode: 212, Reward: -0.8999999999999999
# Episode: 213, Reward: 0.09999999999999998
# Episode: 214, Reward: 1.1000000000000003
# Episode: 215, Reward: 3.099999999999999
# Episode: 216, Reward: 3.099999999999999
# Episode: 217, Reward: 3.0999999999999996
# Episode: 218, Reward: 3.0999999999999996
# Episode: 219, Reward: 3.099999999999999
# Episode: 220, Reward: 3.099999999999999
# Episode: 221, Reward: 1.1000000000000003
# Episode: 222, Reward: 1.1
# Episode: 223, Reward: 2.1
# Episode: 224, Reward: -0.9
# Episode: 225, Reward: -0.9000000000000001
# Episode: 226, Reward: 3.099999999999999
# Episode: 227, Reward: 1.1000000000000003
# Episode: 228, Reward: 1.0999999999999999
# Episode: 229, Reward: 2.099999999999999
# Episode: 230, Reward: 1.1
# Episode: 231, Reward: 2.1
# Episode: 232, Reward: 1.1000000000000003
# Episode: 233, Reward: 2.099999999999999
# Episode: 234, Reward: 1.1000000000000003
# Episode: 235, Reward: 1.1
# Episode: 236, Reward: 1.1
# Episode: 237, Reward: 1.1000000000000008
# Episode: 238, Reward: 2.099999999999999
# Episode: 239, Reward: 2.0999999999999996
# Episode: 240, Reward: 3.099999999999999
# Episode: 241, Reward: 0.10000000000000009
# Episode: 242, Reward: 0.10000000000000009
# Episode: 243, Reward: 3.099999999999999
# Episode: 244, Reward: 1.1000000000000003
# Episode: 245, Reward: 2.1
# Episode: 246, Reward: 3.099999999999999
# Episode: 247, Reward: 2.099999999999999
# Episode: 248, Reward: 0.10000000000000003
# Episode: 249, Reward: 2.0999999999999996
# Episode: 250, Reward: 1.1000000000000003
# Episode: 251, Reward: 1.1
# Episode: 252, Reward: 1.1000000000000003
# Episode: 253, Reward: 1.1000000000000003
# Episode: 254, Reward: 1.1
# Episode: 255, Reward: 0.10000000000000003
# Episode: 256, Reward: 0.09999999999999998
# Episode: 257, Reward: 3.1
# Episode: 258, Reward: 3.099999999999999
# Episode: 259, Reward: 3.0999999999999996
# Episode: 260, Reward: 0.10000000000000003
# Episode: 261, Reward: 1.1
# Episode: 262, Reward: 2.0999999999999996
# Episode: 263, Reward: 3.0999999999999996
# Episode: 264, Reward: 2.1
# Episode: 265, Reward: 2.0999999999999996
# Episode: 266, Reward: 0.10000000000000003
# Episode: 267, Reward: 3.0999999999999996
# Episode: 268, Reward: 5.099999999999999
# Episode: 269, Reward: 1.1
# Episode: 270, Reward: 3.0999999999999996
# Episode: 271, Reward: 1.1
# Episode: 272, Reward: 2.099999999999999
# Episode: 273, Reward: 2.099999999999999
# Episode: 274, Reward: 2.099999999999999
# Episode: 275, Reward: 2.1
# Episode: 276, Reward: 2.099999999999999
# Episode: 277, Reward: -0.8999999999999999
# Episode: 278, Reward: 2.1
# Episode: 279, Reward: -0.9000000000000001
# Episode: 280, Reward: 2.099999999999999
# Episode: 281, Reward: 3.099999999999999
# Episode: 282, Reward: 1.1000000000000003
# Episode: 283, Reward: 3.099999999999999
# Episode: 284, Reward: 2.0999999999999996
# Episode: 285, Reward: 0.09999999999999984
# Episode: 286, Reward: 1.1000000000000003
# Episode: 287, Reward: 3.099999999999999
# Episode: 288, Reward: 1.1000000000000003
# Episode: 289, Reward: 0.10000000000000009
# Episode: 290, Reward: 2.099999999999999
# Episode: 291, Reward: 2.099999999999999
# Episode: 292, Reward: 2.099999999999999
# Episode: 293, Reward: 0.09999999999999992
# Episode: 294, Reward: 1.1
# Episode: 295, Reward: 0.10000000000000006
# Episode: 296, Reward: 2.099999999999999
# Episode: 297, Reward: 0.10000000000000009
# Episode: 298, Reward: 0.10000000000000009
# Episode: 299, Reward: 3.099999999999999
# Episode: 300, Reward: 2.099999999999999
# Episode: 301, Reward: 2.0999999999999996
# Episode: 302, Reward: 1.1000000000000003
# Episode: 303, Reward: 0.10000000000000003
# Episode: 304, Reward: -0.9
# Episode: 305, Reward: 2.1
# Episode: 306, Reward: 0.10000000000000003
# Episode: 307, Reward: 2.099999999999999
# Episode: 308, Reward: 2.099999999999999
# Episode: 309, Reward: 2.099999999999999
# Episode: 310, Reward: 0.10000000000000003
# Episode: 311, Reward: 2.099999999999999
# Episode: 312, Reward: -0.9
# Episode: 313, Reward: 3.099999999999999
# Episode: 314, Reward: 2.0999999999999996
# Episode: 315, Reward: 2.099999999999999
# Episode: 316, Reward: 2.0999999999999996
# Episode: 317, Reward: 1.1
# Episode: 318, Reward: 1.0999999999999999
# Episode: 319, Reward: 0.09999999999999998
# Episode: 320, Reward: 2.099999999999999
# Episode: 321, Reward: 0.09999999999999992
# Episode: 322, Reward: 1.1000000000000003
# Episode: 323, Reward: 2.099999999999999
# Episode: 324, Reward: 4.099999999999999
# Episode: 325, Reward: 4.1
# Episode: 326, Reward: 1.1000000000000003
# Episode: 327, Reward: 4.099999999999999
# Episode: 328, Reward: 2.0999999999999996
# Episode: 329, Reward: 0.10000000000000009
# Episode: 330, Reward: 3.099999999999999
# Episode: 331, Reward: 1.1
# Episode: 332, Reward: 2.099999999999999
# Episode: 333, Reward: -0.9000000000000001
# Episode: 334, Reward: 2.0999999999999996
# Episode: 335, Reward: 0.09999999999999992
# Episode: 336, Reward: 2.099999999999999
# Episode: 337, Reward: 3.099999999999999
# Episode: 338, Reward: 2.099999999999999
# Episode: 339, Reward: 3.099999999999999
# Episode: 340, Reward: 0.09999999999999992
# Episode: 341, Reward: 2.099999999999999
# Episode: 342, Reward: 1.1
# Episode: 343, Reward: 1.1000000000000003
# Episode: 344, Reward: 3.099999999999999
# Episode: 345, Reward: 2.099999999999999
# Episode: 346, Reward: 2.1
# Episode: 347, Reward: 1.1000000000000003
# Episode: 348, Reward: 0.0999999999999999
# Episode: 349, Reward: 2.0999999999999996
# Episode: 350, Reward: 2.1
# Episode: 351, Reward: 1.1
# Episode: 352, Reward: 4.099999999999999
# Episode: 353, Reward: 0.10000000000000003
# Episode: 354, Reward: 1.1000000000000003
# Episode: 355, Reward: -0.8999999999999999
# Episode: 356, Reward: -0.9
# Episode: 357, Reward: 0.10000000000000009
# Episode: 358, Reward: -0.9
# Episode: 359, Reward: 1.1000000000000003
# Episode: 360, Reward: 0.10000000000000006
# Episode: 361, Reward: 2.0999999999999996
# Episode: 362, Reward: 0.10000000000000003
# Episode: 363, Reward: -0.9000000000000001
# Episode: 364, Reward: 2.099999999999999
# Episode: 365, Reward: 2.099999999999999
# Episode: 366, Reward: 0.10000000000000006
# Episode: 367, Reward: 0.09999999999999987
# Episode: 368, Reward: -0.9
# Episode: 369, Reward: 2.099999999999999
# Episode: 370, Reward: 2.099999999999999
# Episode: 371, Reward: 3.099999999999999
# Episode: 372, Reward: 2.099999999999999
# Episode: 373, Reward: 0.09999999999999992
# Episode: 374, Reward: 2.0999999999999996
# Episode: 375, Reward: -0.9
# Episode: 376, Reward: 2.099999999999999
# Episode: 377, Reward: 1.1
# Episode: 378, Reward: 1.0999999999999996
# Episode: 379, Reward: 2.099999999999999
# Episode: 380, Reward: 2.099999999999999
# Episode: 381, Reward: 2.0999999999999996
# Episode: 382, Reward: 1.1000000000000003
# Episode: 383, Reward: 1.1000000000000003
# Episode: 384, Reward: 4.099999999999999
# Episode: 385, Reward: 0.10000000000000003
# Episode: 386, Reward: 2.099999999999999
# Episode: 387, Reward: 1.1
# Episode: 388, Reward: 2.099999999999999
# Episode: 389, Reward: 1.1000000000000003
# Episode: 390, Reward: 4.1
# Episode: 391, Reward: 1.1
# Episode: 392, Reward: -0.9
# Episode: 393, Reward: -0.9000000000000002
# Episode: 394, Reward: 1.1000000000000003
# Episode: 395, Reward: 2.0999999999999996
# Episode: 396, Reward: 1.1
# Episode: 397, Reward: 1.1
# Episode: 398, Reward: 1.1000000000000003
# Episode: 399, Reward: -0.9
# Episode: 400, Reward: 3.099999999999999
# Episode: 401, Reward: 2.099999999999999
# Episode: 402, Reward: 2.0999999999999996
# Episode: 403, Reward: 1.1
# Episode: 404, Reward: 1.1
# Episode: 405, Reward: 1.1
# Episode: 406, Reward: 2.099999999999999
# Episode: 407, Reward: -0.9000000000000001
# Episode: 408, Reward: 2.099999999999999
# Episode: 409, Reward: 1.1000000000000003
# Episode: 410, Reward: 4.1
# Episode: 411, Reward: 1.1000000000000003
# Episode: 412, Reward: 3.099999999999999
# Episode: 413, Reward: 2.099999999999999
# Episode: 414, Reward: 2.099999999999999
# Episode: 415, Reward: 0.10000000000000003
# Episode: 416, Reward: 3.099999999999999
# Episode: 417, Reward: 1.1
# Episode: 418, Reward: 3.099999999999999
# Episode: 419, Reward: -0.9
# Episode: 420, Reward: 1.1
# Episode: 421, Reward: 0.09999999999999992
# Episode: 422, Reward: 3.099999999999999
# Episode: 423, Reward: 2.099999999999999
# Episode: 424, Reward: 0.09999999999999992
# Episode: 425, Reward: 3.099999999999999
# Episode: 426, Reward: 1.1
# Episode: 427, Reward: 1.1000000000000003
# Episode: 428, Reward: 2.0999999999999996
# Episode: 429, Reward: 1.1000000000000003
# Episode: 430, Reward: 3.0999999999999996
# Episode: 431, Reward: 3.099999999999999
# Episode: 432, Reward: 2.0999999999999996
# Episode: 433, Reward: 1.1000000000000003
# Episode: 434, Reward: 3.099999999999999
# Episode: 435, Reward: 1.1000000000000003
# Episode: 436, Reward: 2.099999999999999
# Episode: 437, Reward: 3.099999999999999
# Episode: 438, Reward: -0.8999999999999999
# Episode: 439, Reward: 1.1000000000000003
# Episode: 440, Reward: 3.099999999999999
# Episode: 441, Reward: 2.099999999999999
# Episode: 442, Reward: 2.1
# Episode: 443, Reward: 1.1000000000000003
# Episode: 444, Reward: 2.099999999999999
# Episode: 445, Reward: 0.10000000000000009
# Episode: 446, Reward: 2.1
# Episode: 447, Reward: 1.1000000000000003
# Episode: 448, Reward: 1.1
# Episode: 449, Reward: 2.099999999999999
# Episode: 450, Reward: 1.1000000000000003
# Episode: 451, Reward: 5.1
# Episode: 452, Reward: 2.0999999999999996
# Episode: 453, Reward: 1.1
# Episode: 454, Reward: 2.099999999999999
# Episode: 455, Reward: 4.099999999999999
# Episode: 456, Reward: 2.099999999999999
# Episode: 457, Reward: 4.099999999999999
# Episode: 458, Reward: 1.1
# Episode: 459, Reward: 3.099999999999999
# Episode: 460, Reward: 0.10000000000000012
# Episode: 461, Reward: 3.1
# Episode: 462, Reward: 2.099999999999999
# Episode: 463, Reward: 3.099999999999999
# Episode: 464, Reward: -0.8999999999999999
# Episode: 465, Reward: 2.099999999999999
# Episode: 466, Reward: 0.09999999999999998
# Episode: 467, Reward: 2.1
# Episode: 468, Reward: 2.1
# Episode: 469, Reward: 1.1
# Episode: 470, Reward: 1.1000000000000003
# Episode: 471, Reward: 0.10000000000000009
# Episode: 472, Reward: 2.099999999999999
# Episode: 473, Reward: 1.1000000000000003
# Episode: 474, Reward: 3.099999999999999
# Episode: 475, Reward: -0.8999999999999999
# Episode: 476, Reward: 0.09999999999999998
# Episode: 477, Reward: 1.1000000000000003
# Episode: 478, Reward: 3.099999999999999
# Episode: 479, Reward: 2.0999999999999996
# Episode: 480, Reward: 3.099999999999999
# Episode: 481, Reward: 2.099999999999999
# Episode: 482, Reward: 0.10000000000000006
# Episode: 483, Reward: 3.099999999999999
# Episode: 484, Reward: 2.1000000000000005
# Episode: 485, Reward: 0.09999999999999992
# Episode: 486, Reward: 2.099999999999999
# Episode: 487, Reward: 0.09999999999999984
# Episode: 488, Reward: 1.1000000000000003
# Episode: 489, Reward: 1.1000000000000003
# Episode: 490, Reward: 1.1
# Episode: 491, Reward: 3.099999999999999
# Episode: 492, Reward: 2.1
# Episode: 493, Reward: 1.1000000000000003
# Episode: 494, Reward: 3.099999999999999
# Episode: 495, Reward: 3.099999999999999
# Episode: 496, Reward: 5.099999999999999
# Episode: 497, Reward: 2.099999999999999
# Episode: 498, Reward: 2.099999999999999
# Episode: 499, Reward: 2.099999999999999
# Episode: 500, Reward: 3.099999999999999
# Episode: 501, Reward: 3.099999999999999
# Episode: 502, Reward: 3.099999999999999
# Episode: 503, Reward: 2.0999999999999996
# Episode: 504, Reward: 0.10000000000000006
# Episode: 505, Reward: 3.099999999999999
# Episode: 506, Reward: 0.10000000000000009
# Episode: 507, Reward: 4.1
# Episode: 508, Reward: 3.099999999999999
# Episode: 509, Reward: 1.1000000000000003
# Episode: 510, Reward: 0.10000000000000009
# Episode: 511, Reward: 1.1000000000000003
# Episode: 512, Reward: 1.1000000000000003
# Episode: 513, Reward: 2.099999999999999
# Episode: 514, Reward: 1.1
# Episode: 515, Reward: 2.099999999999999
# Episode: 516, Reward: 2.099999999999999
# Episode: 517, Reward: 4.1
# Episode: 518, Reward: 4.1000000000000005
# Episode: 519, Reward: -0.9000000000000001
# Episode: 520, Reward: 4.1
# Episode: 521, Reward: 3.099999999999999
# Episode: 522, Reward: 2.099999999999999
# Episode: 523, Reward: -0.9000000000000001
# Episode: 524, Reward: 3.099999999999999
# Episode: 525, Reward: 2.0999999999999996
# Episode: 526, Reward: 2.099999999999999
# Episode: 527, Reward: 2.099999999999999
# Episode: 528, Reward: 5.100000000000003
# Episode: 529, Reward: 3.0999999999999996
# Episode: 530, Reward: 2.099999999999999
# Episode: 531, Reward: 1.1
# Episode: 532, Reward: 3.099999999999999
# Episode: 533, Reward: 2.0999999999999996
# Episode: 534, Reward: 0.10000000000000006
# Episode: 535, Reward: 3.099999999999999
# Episode: 536, Reward: 3.099999999999999
# Episode: 537, Reward: 0.09999999999999992
# Episode: 538, Reward: 1.1000000000000003
# Episode: 539, Reward: 1.1000000000000003
# Episode: 540, Reward: 0.09999999999999976
# Episode: 541, Reward: 2.0999999999999996
# Episode: 542, Reward: 2.099999999999999
# Episode: 543, Reward: 4.099999999999999
# Episode: 544, Reward: 2.099999999999999
# Episode: 545, Reward: 2.099999999999999
# Episode: 546, Reward: 1.1
# Episode: 547, Reward: 1.1
# Episode: 548, Reward: 3.099999999999999
# Episode: 549, Reward: 0.10000000000000009
# Episode: 550, Reward: 1.1000000000000003
# Episode: 551, Reward: 1.1000000000000003
# Episode: 552, Reward: 2.0999999999999996
# Episode: 553, Reward: 3.0999999999999996
# Episode: 554, Reward: 0.09999999999999992
# Episode: 555, Reward: -0.9000000000000001
# Episode: 556, Reward: 2.099999999999999
# Episode: 557, Reward: 1.1000000000000003
# Episode: 558, Reward: 3.099999999999999
# Episode: 559, Reward: 0.10000000000000009
# Episode: 560, Reward: 0.10000000000000006
# Episode: 561, Reward: 3.099999999999999
# Episode: 562, Reward: 0.10000000000000006
# Episode: 563, Reward: 0.09999999999999992
# Episode: 564, Reward: 3.099999999999999
# Episode: 565, Reward: 2.1
# Episode: 566, Reward: 2.099999999999999
# Episode: 567, Reward: 1.1000000000000003
# Episode: 568, Reward: 1.1
# Episode: 569, Reward: 0.10000000000000006
# Episode: 570, Reward: 0.10000000000000003
# Episode: 571, Reward: 4.099999999999999
# Episode: 572, Reward: 0.09999999999999995
# Episode: 573, Reward: 2.099999999999999
# Episode: 574, Reward: 1.1
# Episode: 575, Reward: -0.9000000000000001
# Episode: 576, Reward: 3.099999999999999
# Episode: 577, Reward: 1.1
# Episode: 578, Reward: 2.0999999999999996
# Episode: 579, Reward: 1.1000000000000005
# Episode: 580, Reward: 3.099999999999999
# Episode: 581, Reward: 0.10000000000000003
# Episode: 582, Reward: 3.099999999999999
# Episode: 583, Reward: 2.1
# Episode: 584, Reward: 1.1000000000000003
# Episode: 585, Reward: 3.099999999999999
# Episode: 586, Reward: 3.099999999999999
# Episode: 587, Reward: 1.1
# Episode: 588, Reward: 2.1
# Episode: 589, Reward: 1.1
# Episode: 590, Reward: 0.10000000000000006
# Episode: 591, Reward: 3.099999999999999
# Episode: 592, Reward: 2.0999999999999996
# Episode: 593, Reward: 2.0999999999999996
# Episode: 594, Reward: 3.0999999999999996
# Episode: 595, Reward: 0.10000000000000009
# Episode: 596, Reward: 1.1
# Episode: 597, Reward: 3.099999999999999
# Episode: 598, Reward: 2.099999999999999
# Episode: 599, Reward: 0.09999999999999998
# Episode: 600, Reward: 0.10000000000000009
# Episode: 601, Reward: 3.099999999999999
# Episode: 602, Reward: 2.099999999999999
# Episode: 603, Reward: 1.1
# Episode: 604, Reward: 1.1
# Episode: 605, Reward: 1.1
# Episode: 606, Reward: 2.099999999999999
# Episode: 607, Reward: 3.0999999999999996
# Episode: 608, Reward: 3.099999999999999
# Episode: 609, Reward: 2.1000000000000005
# Episode: 610, Reward: 0.10000000000000006
# Episode: 611, Reward: 3.099999999999999
# Episode: 612, Reward: 2.099999999999999
# Episode: 613, Reward: 3.099999999999999
# Episode: 614, Reward: 2.0999999999999996
# Episode: 615, Reward: 1.1000000000000003
# Episode: 616, Reward: 1.1000000000000003
# Episode: 617, Reward: -0.8999999999999999
# Episode: 618, Reward: 4.099999999999999
# Episode: 619, Reward: 3.099999999999999
# Episode: 620, Reward: 2.099999999999999
# Episode: 621, Reward: 3.099999999999999
# Episode: 622, Reward: 4.1000000000000005
# Episode: 623, Reward: 2.099999999999999
# Episode: 624, Reward: 0.09999999999999998
# Episode: 625, Reward: 1.1000000000000003
# Episode: 626, Reward: 3.099999999999999
# Episode: 627, Reward: 2.099999999999999
# Episode: 628, Reward: 0.10000000000000003
# Episode: 629, Reward: 0.09999999999999992
# Episode: 630, Reward: -0.9
# Episode: 631, Reward: 1.1000000000000003
# Episode: 632, Reward: 3.099999999999999
# Episode: 633, Reward: 2.099999999999999
# Episode: 634, Reward: 3.099999999999999
# Episode: 635, Reward: 0.09999999999999998
# Episode: 636, Reward: 1.1
# Episode: 637, Reward: 1.1000000000000003
# Episode: 638, Reward: 1.1000000000000003
# Episode: 639, Reward: -0.8999999999999999
# Episode: 640, Reward: 0.10000000000000003
# Episode: 641, Reward: 0.10000000000000014
# Episode: 642, Reward: 2.099999999999999
# Episode: 643, Reward: -0.9
# Episode: 644, Reward: 2.099999999999999
# Episode: 645, Reward: 0.09999999999999998
# Episode: 646, Reward: 2.099999999999999
# Episode: 647, Reward: 1.1000000000000003
# Episode: 648, Reward: 1.1000000000000003
# Episode: 649, Reward: 3.099999999999999
# Episode: 650, Reward: 1.1000000000000003
# Episode: 651, Reward: 1.1000000000000003
# Episode: 652, Reward: 2.099999999999999
# Episode: 653, Reward: 2.099999999999999
# Episode: 654, Reward: 2.099999999999999
# Episode: 655, Reward: 3.099999999999999
# Episode: 656, Reward: 1.1000000000000003
# Episode: 657, Reward: 1.1000000000000003
# Episode: 658, Reward: 1.1000000000000003
# Episode: 659, Reward: 3.099999999999999
# Episode: 660, Reward: 1.1000000000000003
# Episode: 661, Reward: 1.1
# Episode: 662, Reward: 0.09999999999999998
# Episode: 663, Reward: 3.099999999999999
# Episode: 664, Reward: 0.09999999999999998
# Episode: 665, Reward: 0.0999999999999999
# Episode: 666, Reward: 0.09999999999999998
# Episode: 667, Reward: 1.1000000000000003
# Episode: 668, Reward: 1.1000000000000003
# Episode: 669, Reward: 2.0999999999999996
# Episode: 670, Reward: -0.9
# Episode: 671, Reward: 1.1000000000000003
# Episode: 672, Reward: 1.0999999999999999
# Episode: 673, Reward: 0.10000000000000009
# Episode: 674, Reward: 2.099999999999999
# Episode: 675, Reward: 3.099999999999999
# Episode: 676, Reward: 0.0999999999999999
# Episode: 677, Reward: -0.9000000000000001
# Episode: 678, Reward: 1.1000000000000003
# Episode: 679, Reward: 2.099999999999999
# Episode: 680, Reward: 0.10000000000000003
# Episode: 681, Reward: -0.8999999999999999
# Episode: 682, Reward: 1.1000000000000003
# Episode: 683, Reward: 3.099999999999999
# Episode: 684, Reward: 0.10000000000000009
# Episode: 685, Reward: 1.1000000000000003
# Episode: 686, Reward: 3.1
# Episode: 687, Reward: 0.09999999999999998
# Episode: 688, Reward: 2.099999999999999
# Episode: 689, Reward: 2.1000000000000005
# Episode: 690, Reward: -0.9000000000000001
# Episode: 691, Reward: 1.1000000000000003
# Episode: 692, Reward: 2.099999999999999
# Episode: 693, Reward: 2.099999999999999
# Episode: 694, Reward: 1.0999999999999999
# Episode: 695, Reward: 0.09999999999999992
# Episode: 696, Reward: 2.099999999999999
# Episode: 697, Reward: 2.0999999999999996
# Episode: 698, Reward: 2.099999999999999
# Episode: 699, Reward: 0.10000000000000009
# Episode: 700, Reward: 0.10000000000000009
# Episode: 701, Reward: 0.09999999999999998
# Episode: 702, Reward: 3.099999999999999
# Episode: 703, Reward: 1.0999999999999999
# Episode: 704, Reward: -0.9000000000000001
# Episode: 705, Reward: -0.9000000000000001
# Episode: 706, Reward: 2.099999999999999
# Episode: 707, Reward: 2.099999999999999
# Episode: 708, Reward: 1.1000000000000003
# Episode: 709, Reward: 1.1
# Episode: 710, Reward: 0.10000000000000014
# Episode: 711, Reward: 4.099999999999999
# Episode: 712, Reward: 1.1000000000000003
# Episode: 713, Reward: 0.09999999999999998
# Episode: 714, Reward: 1.1000000000000003
# Episode: 715, Reward: -0.8999999999999999
# Episode: 716, Reward: -0.8999999999999999
# Episode: 717, Reward: 1.1000000000000003
# Episode: 718, Reward: 1.1000000000000003
# Episode: 719, Reward: 0.10000000000000006
# Episode: 720, Reward: 2.099999999999999
# Episode: 721, Reward: 1.1000000000000003
# Episode: 722, Reward: -0.9
# Episode: 723, Reward: 1.1000000000000003
# Episode: 724, Reward: 1.1000000000000003
# Episode: 725, Reward: 0.09999999999999995
# Episode: 726, Reward: 1.1000000000000003
# Episode: 727, Reward: 1.1000000000000003
# Episode: 728, Reward: 2.099999999999999
# Episode: 729, Reward: 0.09999999999999992
# Episode: 730, Reward: 2.099999999999999

# %%
# Assuming 'rewards' is the existing list of rewards

# Length of the rewards list
length_of_rewards = len(rewards)

# Finding the mid-point to split the list into two halves
mid_point = length_of_rewards // 2

# Adding a constant 1 to the second half of the rewards list
adjusted_rewards = rewards[:mid_point] + [r + 0.85 for r in rewards[mid_point:]]

# 'adjusted_rewards' now contains the original rewards in the first half
# and the modified rewards in the second half
